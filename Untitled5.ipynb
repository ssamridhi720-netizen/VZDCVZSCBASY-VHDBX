# %% [markdown]
# <a href="https://colab.research.google.com/github/ssamridhi720-netizen/VZDCVZSCBASY-VHDBX/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Calculate Euclidean distance
def euclidean_distance(point1, point2):
    return np.sqrt(np.sum((np.array(point1) - np.array(point2)) ** 2))

# %%
point1 = [3,4]
point2 = [5,6]
distance = euclidean_distance(point1, point2)
print(f"Euclidean Distance: {distance}")
# Out:
# Euclidean Distance: 2.8284271247461903

# %%
# Plotting the points and the Euclidean distance
plt.figure()
plt.scatter(*zip(*[point1, point2]), color=['black', 'blue'])
plt.plot([point1[0], point2[0]], [point1[1], point2[1]], color='red')
plt.text((point1[0] + point2[0]) / 2, (point1[1] + point2[1]) / 2, f'{distance:.2f}', color='red')
plt.title('Euclidean Distance')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
point1 = [22,30]
point2 = [16,20]

# %%
# Calculate Manhattan distance
def manhattan_distance(point1, point2):
    return np.sum(np.abs(np.array(point1) - np.array(point2)))

distance = manhattan_distance(point1, point2)
print(f"Manhattan Distance: {distance}")
# Out:
# Manhattan Distance: 16

# %%
# Plotting the points and the Manhattan distance
plt.figure()
plt.scatter(*zip(*[point1, point2]), color=['red', 'blue'])
plt.plot([point1[0], point1[0]], [point1[1], point2[1]], color='black', linestyle='--')
plt.plot([point1[0], point2[0]], [point2[1], point2[1]], color='black', linestyle='--')
plt.text((point1[0] + point2[0]) / 2, (point1[1] + point2[1]) / 2, f'{distance:.2f}', color='black')
plt.title('Manhattan Distance')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()
